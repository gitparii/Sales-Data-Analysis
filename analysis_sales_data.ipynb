# %% [markdown]
# # Retail sales data analysis project

# %%
import pandas as pd

# %%
df = pd.read_csv('Financials.csv')

# %%
df.head()
# Out:
#       Segment  Country     Product   Discount Band   Units Sold   \
# 0  Government   Canada   Carretera            None    $1,618.50
# 1  Government  Germany   Carretera            None    $1,321.00
# 2   Midmarket   France   Carretera            None    $2,178.00
# 3   Midmarket  Germany   Carretera            None      $888.00
# 4   Midmarket   Mexico   Carretera            None    $2,470.00
#
#    Manufacturing Price   Sale Price   Gross Sales   Discounts         Sales   \
# 0                $3.00       $20.00    $32,370.00        $-      $32,370.00
# 1                $3.00       $20.00    $26,420.00        $-      $26,420.00
# 2                $3.00       $15.00    $32,670.00        $-      $32,670.00
# 3                $3.00       $15.00    $13,320.00        $-      $13,320.00
# 4                $3.00       $15.00    $37,050.00        $-      $37,050.00
#
#           COGS        Profit         Date  Month Number  Month Name   Year
# 0   $16,185.00    $16,185.00   01/01/2014             1     January   2014
# 1   $13,210.00    $13,210.00   01/01/2014             1     January   2014
# 2   $21,780.00    $10,890.00   01/06/2014             6        June   2014
# 3    $8,880.00     $4,440.00   01/06/2014             6        June   2014
# 4   $24,700.00    $12,350.00   01/06/2014             6        June   2014

# %%
df.tail()
# Out:
#               Segment                   Country    Product   Discount Band   \
# 695    Small Business                    France   Amarilla            High
# 696    Small Business                    Mexico   Amarilla            High
# 697        Government                    Mexico    Montana            High
# 698        Government                    Canada      Paseo            High
# 699  Channel Partners  United States of America        VTT            High
#
#      Units Sold   Manufacturing Price   Sale Price     Gross Sales   \
# 695   $2,475.00               $260.00      $300.00    $7,42,500.00
# 696     $546.00               $260.00      $300.00    $1,63,800.00
# 697   $1,368.00                 $5.00        $7.00       $9,576.00
# 698     $723.00                $10.00        $7.00       $5,061.00
# 699   $1,806.00               $250.00       $12.00      $21,672.00
#
#          Discounts           Sales            COGS        Profit         Date  \
# 695   $1,11,375.00    $6,31,125.00    $6,18,750.00    $12,375.00   01/03/2014
# 696     $24,570.00    $1,39,230.00    $1,36,500.00     $2,730.00   01/10/2014
# 697      $1,436.40       $8,139.60       $6,840.00     $1,299.60   01/02/2014
# 698        $759.15       $4,301.85       $3,615.00       $686.85   01/04/2014
# 699      $3,250.80      $18,421.20       $5,418.00    $13,003.20   01/05/2014
#
#      Month Number  Month Name   Year
# 695             3       March   2014
# 696            10     October   2014
# 697             2    February   2014
# 698             4       April   2014
# 699             5         May   2014

# %%
df.isnull().sum()
# Out:
# Segment                  0
# Country                  0
#  Product                 0
#  Discount Band           0
#  Units Sold              0
#  Manufacturing Price     0
#  Sale Price              0
#  Gross Sales             0
#  Discounts               0
#   Sales                  0
#  COGS                    0
#  Profit                  0
# Date                     0
# Month Number             0
#  Month Name              0
# Year                     0
# dtype: int64

# %%
#colum names have error -> to make them error free we can use strip function to remove extra spaces
df.columns=df.columns.str.strip()

# %%
df.isnull().sum()
# Out:
# Segment                0
# Country                0
# Product                0
# Discount Band          0
# Units Sold             0
# Manufacturing Price    0
# Sale Price             0
# Gross Sales            0
# Discounts              0
# Sales                  0
# COGS                   0
# Profit                 0
# Date                   0
# Month Number           0
# Month Name             0
# Year                   0
# dtype: int64

# %%
df.dtypes
# Out:
# Segment                object
# Country                object
# Product                object
# Discount Band          object
# Units Sold             object
# Manufacturing Price    object
# Sale Price             object
# Gross Sales            object
# Discounts              object
# Sales                  object
# COGS                   object
# Profit                 object
# Date                   object
# Month Number            int64
# Month Name             object
# Year                    int64
# dtype: object

# %%
#columns like sold units has integer values as we can see but due to dollor sign it is considered as object data type so we have to remove dollor sign and convert into int data type

dollor=['Units Sold','Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts', 'Sales', 'COGS', 'Profit']
for columns in dollor:
    df[columns]=df[columns].str.replace('$','', regex = False)

# %%
df.dtypes
# Out:
# Segment                object
# Country                object
# Product                object
# Discount Band          object
# Units Sold             object
# Manufacturing Price    object
# Sale Price             object
# Gross Sales            object
# Discounts              object
# Sales                  object
# COGS                   object
# Profit                 object
# Date                   object
# Month Number            int64
# Month Name             object
# Year                    int64
# dtype: object

# %%
df.head()
# Out:
#       Segment  Country      Product Discount Band  Units Sold  \
# 0  Government   Canada   Carretera          None    1,618.50
# 1  Government  Germany   Carretera          None    1,321.00
# 2   Midmarket   France   Carretera          None    2,178.00
# 3   Midmarket  Germany   Carretera          None      888.00
# 4   Midmarket   Mexico   Carretera          None    2,470.00
#
#   Manufacturing Price Sale Price  Gross Sales Discounts        Sales  \
# 0               3.00      20.00    32,370.00       -      32,370.00
# 1               3.00      20.00    26,420.00       -      26,420.00
# 2               3.00      15.00    32,670.00       -      32,670.00
# 3               3.00      15.00    13,320.00       -      13,320.00
# 4               3.00      15.00    37,050.00       -      37,050.00
#
#           COGS       Profit        Date  Month Number Month Name  Year
# 0   16,185.00    16,185.00   01/01/2014             1   January   2014
# 1   13,210.00    13,210.00   01/01/2014             1   January   2014
# 2   21,780.00    10,890.00   01/06/2014             6      June   2014
# 3    8,880.00     4,440.00   01/06/2014             6      June   2014
# 4   24,700.00    12,350.00   01/06/2014             6      June   2014

# %%
df['Discounts']=df['Discounts'].str.replace('-','0', regex=False)

# %%
df.head()
# Out:
#       Segment  Country      Product Discount Band Units Sold  \
# 0  Government   Canada   Carretera          None    1618.50
# 1  Government  Germany   Carretera          None    1321.00
# 2   Midmarket   France   Carretera          None    2178.00
# 3   Midmarket  Germany   Carretera          None     888.00
# 4   Midmarket   Mexico   Carretera          None    2470.00
#
#   Manufacturing Price Sale Price Gross Sales Discounts       Sales  \
# 0               3.00      20.00    32370.00       0      32370.00
# 1               3.00      20.00    26420.00       0      26420.00
# 2               3.00      15.00    32670.00       0      32670.00
# 3               3.00      15.00    13320.00       0      13320.00
# 4               3.00      15.00    37050.00       0      37050.00
#
#          COGS      Profit        Date  Month Number Month Name  Year
# 0   16185.00    16185.00   01/01/2014             1   January   2014
# 1   13210.00    13210.00   01/01/2014             1   January   2014
# 2   21780.00    10890.00   01/06/2014             6      June   2014
# 3    8880.00     4440.00   01/06/2014             6      June   2014
# 4   24700.00    12350.00   01/06/2014             6      June   2014

# %%
for columns in dollor:
    df[columns]= df[columns].str.replace(',','',regex=False)

# %%
df.head()
# Out:
#       Segment  Country      Product Discount Band Units Sold  \
# 0  Government   Canada   Carretera          None    1618.50
# 1  Government  Germany   Carretera          None    1321.00
# 2   Midmarket   France   Carretera          None    2178.00
# 3   Midmarket  Germany   Carretera          None     888.00
# 4   Midmarket   Mexico   Carretera          None    2470.00
#
#   Manufacturing Price Sale Price Gross Sales Discounts       Sales  \
# 0               3.00      20.00    32370.00       0      32370.00
# 1               3.00      20.00    26420.00       0      26420.00
# 2               3.00      15.00    32670.00       0      32670.00
# 3               3.00      15.00    13320.00       0      13320.00
# 4               3.00      15.00    37050.00       0      37050.00
#
#          COGS      Profit        Date  Month Number Month Name  Year
# 0   16185.00    16185.00   01/01/2014             1   January   2014
# 1   13210.00    13210.00   01/01/2014             1   January   2014
# 2   21780.00    10890.00   01/06/2014             6      June   2014
# 3    8880.00     4440.00   01/06/2014             6      June   2014
# 4   24700.00    12350.00   01/06/2014             6      June   2014

# %%
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price             float64
# Gross Sales            float64
# Discounts              float64
# Sales                  float64
# COGS                   float64
# Profit                  object
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
df['Profit']
# Out:
# 0       16185.00
# 1       13210.00
# 2       10890.00
# 3        4440.00
# 4       12350.00
#           ...
# 695     12375.00
# 696      2730.00
# 697      1299.60
# 698       686.85
# 699     13003.20
# Name: Profit, Length: 700, dtype: object

# %%
df['Profit'].unique()
# Out:
# array([' 16185.00 ', ' 13210.00 ', ' 10890.00 ', ' 4440.00 ',
#        ' 12350.00 ', ' 136170.00 ', ' 4605.00 ', ' 22662.00 ',
#        ' 18990.00 ', ' 13905.00 ', ' 13327.50 ', ' 47900.00 ',
#        ' 4292.00 ', ' 1725.00 ', ' 3075.00 ', ' 2920.00 ', ' 4870.00 ',
#        ' 90540.00 ', ' 3303.00 ', ' 1766.00 ', ' 2745.00 ', ' 39400.00 ',
#        ' 12360.00 ', ' 2286.00 ', ' 155250.00 ', ' 8208.00 ',
#        ' 10760.00 ', ' 18170.00 ', ' 2986.00 ', ' 9020.00 ', ' 19449.00 ',
#        ' 14105.00 ', ' 100050.00 ', ' 25542.00 ', ' 137430.00 ',
#        ' 107550.00 ', ' 247500.00 ', ' 17577.00 ', ' 21097.50 ',
#        ' 3372.00 ', ' 19269.00 ', ' 7613.85 ', ' 11135.60 ', ' 1987.90 ',
#        ' 1233.27 ', ' 2559.18 ', ' 16499.04 ', ' 104665.00 ', ' 4880.97 ',
#        ' 12831.60 ', ' 1237.50 ', ' 23718.48 ', ' 6802.08 ', ' 23218.00 ',
#        ' 120840.50 ', ' 186407.50 ', ' 10737.90 ', ' 108147.00 ',
#        ' 13479.90 ', ' 3531.90 ', ' 117406.00 ', ' 2486.25 ', ' 7342.90 ',
#        ' 8670.53 ', ' 2726.25 ', ' 2951.25 ', ' 6836.25 ', ' 3622.95 ',
#        ' 136535.00 ', ' 37867.20 ', ' 698.66 ', ' 3461.25 ', ' 4037.56 ',
#        ' 507.59 ', ' 81612.75 ', ' 46342.00 ', ' 6540.00 ', ' 17662.32 ',
#        ' 1556.85 ', ' 1856.25 ', ' 11344.20 ', ' 9416.00 ', ' 3989.70 ',
#        ' 236716.00 ', ' 10003.92 ', ' 15033.60 ', ' 6044.40 ',
#        ' 4150.00 ', ' 11106.10 ', ' 40392.00 ', ' 76032.00 ', ' 1655.00 ',
#        ' 2022.50 ', ' 5362.50 ', ' 15636.60 ', ' 84304.00 ', ' 6822.50 ',
#        ' 9047.50 ', ' 3744.18 ', ' 9241.80 ', ' 9495.84 ', ' 246178.00 ',
#        ' 238791.00 ', ' 5222.40 ', ' 22078.00 ', ' 161020.00 ',
#        ' 11396.00 ', ' 48444.00 ', ' 5690.00 ', ' 11865.60 ', ' 9033.60 ',
# %%
df['Profit']=df['Profit'].str.strip()

# %%
df['Profit'] = df['Profit'].str.replace('(', '-', regex=False)
df['Profit'] = df['Profit'].str.replace(')', '', regex=False)

# %%
df['Profit'] = df['Profit'].replace('-', '')

# %%
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price             float64
# Gross Sales            float64
# Discounts              float64
# Sales                  float64
# COGS                   float64
# Profit                  object
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
df['Profit'] = pd.to_numeric(df['Profit'], errors='coerce')

# %%
df['Profit'] = df['Profit'].astype(float)

# %%
df.dtypes
# Out:
# Segment                 object
# Country                 object
# Product                 object
# Discount Band           object
# Units Sold             float64
# Manufacturing Price    float64
# Sale Price             float64
# Gross Sales            float64
# Discounts              float64
# Sales                  float64
# COGS                   float64
# Profit                 float64
# Date                    object
# Month Number             int64
# Month Name              object
# Year                     int64
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price           float64
# Sale Price                    float64
# Gross Sales                   float64
# Discounts                     float64
# Sales                         float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# Month Number                    int64
# Month Name                     object
# Year                            int64
# dtype: object

# %%
#We dont need year, month number and month name column because we can get these values from Date column so we can drop it

df=df.drop(['Month Number', 'Month Name', 'Year'], axis=1)

# %%
df.dtypes
# Out:
# Segment                        object
# Country                        object
# Product                        object
# Discount Band                  object
# Units Sold                    float64
# Manufacturing Price           float64
# Sale Price                    float64
# Gross Sales                   float64
# Discounts                     float64
# Sales                         float64
# COGS                          float64
# Profit                        float64
# Date                   datetime64[ns]
# dtype: object

# %% [markdown]
# # Data analysis and Visualisation

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Country wise analysis

# %%
group=df.groupby('Country').agg({'Sales':'sum', 'Profit':'sum', 'Units Sold':'sum', 'COGS':'sum'}).reset_index()

# %%
group.head()
# Out:
#                     Country        Sales      Profit  Units Sold        COGS
# 0                    Canada  24887654.89  3529228.89    247428.5  21358426.0
# 1                    France  24354172.29  3781020.79    240931.0  20573151.5
# 2                   Germany  23505340.82  3680388.82    201494.0  19824952.0
# 3                    Mexico  20949352.11  2907523.11    203325.0  18041829.0
# 4  United States of America  25029830.18  2995540.68    232627.5  22034289.5

# %%
bar_width = 0.3
plt.figure(figsize=(10,6))
# Calculate the x positions for the bars
x = np.arange(len(group['Country']))
plt.bar(x-bar_width, group['Sales'], bar_width, label='Sales')

plt.xticks(x, group['Country'])
plt.legend()
plt.show()

# %% [markdown]
# We can see that highest sale is noticed in USA and in Canada and lowest sale is recorded in Mexico

# %%
plt.figure(figsize=(10,6))
x = np.arange(len(group['Country']))
plt.bar(x-bar_width, group['Sales'], bar_width, label='Sales')
plt.bar(x, group['COGS'], bar_width, label='COGS')
# plt.bar(x+bar_width, group['Units Sold'], bar_width, label='Units Sold')

# plt.xlabel('Country')
# plt.ylabel('Values')
plt.xticks(x, group['Country'])
plt.legend()
plt.show()

# %% [markdown]
# We can see that Sales is more than the COGS(Cost of Gross Sale) it means company is in profit

# %%
plt.figure(figsize=(10,6))

plt.pie(group['Profit'], labels=group['Country'], autopct='%1.1f%%', startangle=140)
plt.title('Country wise Profit')
plt.show()

# %% [markdown]
# Product wise analysis

# %%
group_product=df.groupby('Product').agg({'Units Sold':'sum', 'Manufacturing Price':'mean', 'Sale Price':'mean', 'Gross Sales':'sum', 'Profit':'sum', 'COGS':'sum'}).reset_index()

# %%
group_product['Gross Margin']=group_product['Sale Price']-group_product['Manufacturing Price']

# %%
plt.figure(figsize=(10,6))

categories=group_product['Product']
margin_values=group_product['Gross Margin']
# Create a bar chart
plt.bar(categories, margin_values, label='Gross Margin')
plt.xticks(group_product['Product'])

plt.show()

# %% [markdown]
# From above figure we can see that Product 'Amarilla' and product 'VTT' has negative gross margin and product 'Velo' has very low margin

# %%
plt.figure(figsize=(10,6))

plt.pie(group_product['Profit'], labels=group_product['Product'], autopct='%1.1f%%', startangle=140)
plt.title('Product wise Profit')
plt.show()

# %% [markdown]
# From here we can see that Paseo has highest profit and Montana have low profit

# %%
plt.figure(figsize=(10,6))
x = np.arange(len(group_product['Product']))
plt.bar(x-bar_width, group_product['Gross Sales'], bar_width, label='Sales')
plt.bar(x, group_product['COGS'], bar_width, label='COGS')
# plt.bar(x+bar_width, group['Units Sold'], bar_width, label='Units Sold')

# plt.xlabel('Country')
# plt.ylabel('Values')
plt.xticks(x, group_product['Product'])
plt.legend()
plt.show()

# %% [markdown]
# Sales of Paseo is much more than other Products and Carretera has the low sales

# %%
bar_width = 0.3
plt.figure(figsize=(10,6))
# Calculate the x positions for the bars
x = np.arange(len(group_product['Product']))
plt.bar(x-bar_width, group_product['Units Sold'], bar_width, label='Units Sold')

plt.xticks(x, group_product['Product'])
plt.legend()
plt.show()

# %% [markdown]
# From here we can clearly see that Paseo is the product which sells maximum

# %% [markdown]
# Sector wise analysis

# %%
group_segment=df.groupby('Segment').agg({'Units Sold':'sum', 'Gross Sales':'sum', 'Profit':'sum', 'COGS':'sum'}).reset_index()

# %%
plt.figure(figsize=(10,6))

plt.bar(group_segment['Segment'], group_segment['Profit'])
plt.show()

# %% [markdown]
# Goverment segment gives most profit and Midmarket gives least profit

# %%
plt.figure(figsize=(10,6))
x = np.arange(len(group_segment['Segment']))
plt.bar(x-bar_width, group_segment['Gross Sales'], bar_width, label='Sales')
plt.bar(x, group_segment['COGS'], bar_width, label='COGS')
# plt.bar(x+bar_width, group['Units Sold'], bar_width, label='Units Sold')

# plt.xlabel('Country')
# plt.ylabel('Values')
plt.xticks(x, group_segment['Segment'])
plt.legend()
plt.show()

# %% [markdown]
# In the Enterprise sector cost of sales and sales is almost same so we can say that margin in that sector could be low and in goverment sector difference between Sales and COGS is more means this sector has more margin

# %%
bar_width = 0.3
plt.figure(figsize=(10,6))
# Calculate the x positions for the bars
x = np.arange(len(group_segment['Segment']))
plt.bar(x-bar_width, group_segment['Units Sold'], bar_width, label='Units Sold')

plt.xticks(x,group_segment['Segment'])
plt.legend()
plt.show()

# %% [markdown]
# more units are sold in goverment sector then mid market and least units are sold in small business
